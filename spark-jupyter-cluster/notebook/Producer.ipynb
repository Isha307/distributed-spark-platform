# %%
from kafka import KafkaProducer
import json
import time
import random

producer = KafkaProducer(
    bootstrap_servers='kafka:9092',
    value_serializer=lambda v: json.dumps(v).encode('utf-8')
)

actions = [
    "login",
    "purchase",
    "logout",
    "add_to_cart"
]

for i in range(20):

    event = {
        "user_id": random.randint(1, 100),
        "action": random.choice(actions),
        "amount": random.randint(10, 500)
    }

    producer.send(
        "user-events",
        event
    )

    print("sent:", event)

    time.sleep(1)
# Out:
# sent: {'user_id': 41, 'action': 'login', 'amount': 44}
# sent: {'user_id': 17, 'action': 'purchase', 'amount': 363}
# sent: {'user_id': 31, 'action': 'logout', 'amount': 388}
# sent: {'user_id': 89, 'action': 'logout', 'amount': 363}
# sent: {'user_id': 74, 'action': 'add_to_cart', 'amount': 206}
# sent: {'user_id': 9, 'action': 'logout', 'amount': 210}
# sent: {'user_id': 72, 'action': 'login', 'amount': 104}
# sent: {'user_id': 39, 'action': 'purchase', 'amount': 417}
# sent: {'user_id': 85, 'action': 'add_to_cart', 'amount': 484}
# sent: {'user_id': 73, 'action': 'logout', 'amount': 229}
# sent: {'user_id': 95, 'action': 'add_to_cart', 'amount': 338}
# sent: {'user_id': 28, 'action': 'login', 'amount': 363}
# sent: {'user_id': 43, 'action': 'purchase', 'amount': 76}
# sent: {'user_id': 97, 'action': 'add_to_cart', 'amount': 183}
# sent: {'user_id': 35, 'action': 'login', 'amount': 30}
# sent: {'user_id': 16, 'action': 'logout', 'amount': 191}
# sent: {'user_id': 18, 'action': 'add_to_cart', 'amount': 262}
# sent: {'user_id': 8, 'action': 'add_to_cart', 'amount': 279}
# sent: {'user_id': 63, 'action': 'add_to_cart', 'amount': 426}
# sent: {'user_id': 25, 'action': 'purchase', 'amount': 50}
